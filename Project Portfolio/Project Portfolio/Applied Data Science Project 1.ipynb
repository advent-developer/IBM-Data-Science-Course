# %% [markdown]
# # Applied Data Science Project 1

# %% [markdown]
# ## Data Collection

# %%
# !pip install bs4
# !pip install lxml==4.6.4
# !pip install html5lib==1.1

# %%
import requests
import io
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_csv('C:/Users/ASUSTUF/Desktop/IBM review 1/Project Portfolio/Dataset/Phil_data/P_Data_Extract_From_World_Development_Indicators/data.csv')  # load the data locally

# %%
df.head(10)
# Out:
#   Country Name Country Code  \
# 0  Philippines          PHL
# 1  Philippines          PHL
# 2  Philippines          PHL
# 3  Philippines          PHL
# 4  Philippines          PHL
# 5  Philippines          PHL
# 6  Philippines          PHL
# 7  Philippines          PHL
# 8  Philippines          PHL
# 9  Philippines          PHL
#
#                                          Series Name        Series Code  \
# 0                                  Population, total        SP.POP.TOTL
# 1                       Population growth (annual %)        SP.POP.GROW
# 2                              Surface area (sq. km)     AG.SRF.TOTL.K2
# 3  Population density (people per sq. km of land ...        EN.POP.DNST
# 4  Poverty headcount ratio at national poverty li...        SI.POV.NAHC
# 5  Poverty headcount ratio at $2.15 a day (2017 P...        SI.POV.DDAY
# 6                    GNI, Atlas method (current US$)     NY.GNP.ATLS.CD
# ...

# %%
len(df)
# Out:
# 60

# %%
df.head(60)
# Out:
#                                         Country Name Country Code  \
# 0                                        Philippines          PHL
# 1                                        Philippines          PHL
# 2                                        Philippines          PHL
# 3                                        Philippines          PHL
# 4                                        Philippines          PHL
# 5                                        Philippines          PHL
# 6                                        Philippines          PHL
# 7                                        Philippines          PHL
# 8                                        Philippines          PHL
# 9                                        Philippines          PHL
# 10                                       Philippines          PHL
# 11                                       Philippines          PHL
# 12                                       Philippines          PHL
# ...
