# %%
# !pip install bs4
# !pip install lxml==4.6.4
# !pip install html5lib==1.1 
import pandas as pd
import requests

# %%
# import the url of the stock data 
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/netflix_data_webpage.html'

# %%
# identify the data type so that in loading the data to pandas the appropriate reading function can be made

df = pd.read_html(url, flavor = 'bs4')
df.head()  # the output will be in error it says list object has no attribute head.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       1 # identify the data type so that in loading the data to pandas the appropriate reading function can be made
#       3 df = pd.read_html(url, flavor = 'bs4')
# ----> 4 df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
len(df)
# Out:
# 1

# %%
df[0]  #access the table
# Out:
#                                                  Date  \
# 0                                        Jun 01, 2021
# 1                                        May 01, 2021
# 2                                        Apr 01, 2021
# 3                                        Mar 01, 2021
# 4                                        Feb 01, 2021
# ..                                                ...
# 66                                       Dec 01, 2015
# 67                                       Nov 01, 2015
# 68                                       Oct 01, 2015
# 69                                       Sep 01, 2015
# 70  *Close price adjusted for splits.**Adjusted cl...
#
#                                                  Open  \
# 0                                              504.01
# 1                                              512.65
# 2                                              529.93
# 3                                              545.57
# ...
